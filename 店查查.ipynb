# %%
from IPython.core.interactiveshell import InteractiveShell  #执行该代码可以使得当前nb支持多输出
InteractiveShell.ast_node_interactivity = "all" 
import numpy as np
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
pd.options.display.max_rows = 8  
# %matplotlib inline

# %%
import time
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import json

data=pd.read_excel(r"data/taobao/new/天猫食品店铺数据.xlsx")
name=data['店铺名字']
browser = webdriver.Chrome()
browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    "source": """
                                Object.defineProperty(navigator, 'webdriver', {
                                  get: () => Chrome
                                })
                              """
})

username='' #用户账号
password=''  #密码  

browser.get("https://www.dianchacha.com/")
browser.maximize_window()

browser.find_element_by_xpath('//*[@id="J_DialogRegister"]').click()
time.sleep(2)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[1]/li[2]').click()
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/div[1]/input').send_keys(username)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/div[2]/input').send_keys(password)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/button').click()
print("登录成功")

time.sleep(3)
# Out:
# 登录成功

# %%
#需要收集的数据
data_list = []


browser.find_element_by_xpath('/html/body/div[2]/div[1]/div/form/input').send_keys(value) # 将查询的值放入输入框
browser.find_element_by_xpath('/html/body/div[2]/div[1]/div/form/button').click()


for i,value in enumerate(name):

    try:
        #跳转到新弹出的额界面
        browser.get("https://www.dianchacha.com/search/?k=" + value)

        WebDriverWait(browser, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="J_Search"]')))  #加载


        data_list.append({
                '店铺名字': value,
                '描述相符': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[3]/div[1]/a/span').text,
                '服务态度': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[4]/div[1]/a/span').text,
                '物流服务': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[5]/div/a/span').text,
                '宝贝数': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[2]/li[1]/p[2]/a').text,
                '月销量': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[2]/li[2]/p[2]').text,
                '所在地区': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[3]/div[2]').text,
                '开店时间': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[2]/div[2]').text,
                '店铺收藏数': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[4]/div[2]').text,
                '关联的店铺': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[7]/a[1]').text,

        })

        time.sleep(10)

        print("下载成功")
        print(data_list)
        pd.DataFrame(data_list).to_excel(r"data/tmp/shipin.xlsx")
    except Exception as e:
            print(e)
            pass
        
pd.DataFrame(data_list).to_excel(r"data/tmp/shipin.xlsx")
# Out:
# 下载成功
# [{'店铺名字': '百草味旗舰店', '描述相符': '高于15.46%', '服务态度': '高于10.19%', '物流服务': '高于8.94%', '宝贝数': '618', '月销量': '2,590,082', '所在地区': '所在地区： 浙江省杭州市', '开店时间': '开店时间： 2010-11-23 [ 10 年前 ]', '店铺收藏数': '店铺收藏数： 40,233,861', '关联的店铺': 'wut旗舰店'}]
# [Errno 13] Permission denied: 'data/tmp/shipin.xlsx'
# 下载成功
# [{'店铺名字': '百草味旗舰店', '描述相符': '高于15.46%', '服务态度': '高于10.19%', '物流服务': '高于8.94%', '宝贝数': '618', '月销量': '2,590,082', '所在地区': '所在地区： 浙江省杭州市', '开店时间': '开店时间： 2010-11-23 [ 10 年前 ]', '店铺收藏数': '店铺收藏数： 40,233,861', '关联的店铺': 'wut旗舰店'}, {'店铺名字': '三只松鼠旗舰店', '描述相符': '高于26.88%', '服务态度': '高于15.34%', '物流服务': '高于8.98%', '宝贝数': '663', '月销量': '2,548,156', '所在地区': '所在地区： 安徽省芜湖市', '开店时间': '开店时间： 2012-05-03 [ 9 年前 ]', '店铺收藏数': '店铺收藏数： 42,926,023', '关联的店铺': '淘灵果旗舰店'}]
# [Errno 13] Permission denied: 'data/tmp/shipin.xlsx'
# 下载成功
# ...

# %%
data=pd.read_excel(r"data/taobao/new/天猫食品店铺数据.xlsx")
name=data['店铺名字']
data_list = []

for i,value in enumerate(name):

    #跳转到新弹出的额界面
    string = "https://www.dianchacha.com/search/?k=" + value
    data_list.append(string)
pd.DataFrame(data_list).to_excel(r"data/tmp/list.xlsx")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time

browser = webdriver.Chrome()



username='13416078207'
password='jiqixuexi666'    

browser.get("https://www.dianchacha.com/")
browser.maximize_window()

browser.find_element_by_xpath('//*[@id="J_DialogRegister"]').click()
time.sleep(2)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[1]/li[2]').click()
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/div[1]/input').send_keys(username)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/div[2]/input').send_keys(password)
browser.find_element_by_xpath('/html/body/div[6]/div/div/div/ul[2]/li[2]/form/button').click()

time.sleep(5)

cookies = browser.get_cookies()
#     print( cookies)
request_cookies = {item.get('name'): item.get('value') for item in cookies}
print(request_cookies)
# Out:
# {'Hm_lpvt_2dc49552d570922026e5fcb79894c7b3': '1624707856', 'Hm_lpvt_3a75bcb07225c9d03aae2d67edca6226': '1624707856', 'Hm_lvt_2dc49552d570922026e5fcb79894c7b3': '1624707851', '_sess_remember': '595828b27a2b0ac7a18c2e7aa77225f2', 'Hm_lvt_3a75bcb07225c9d03aae2d67edca6226': '1624707851', '_dcc_session': 'm5bvjmbp77e0rvmgajeqoj1osu', 'acw_tc': '781bad2916247078468348957e218ec230a3c3fdaecec069a3e67342a5214f'}

# %%
import requests
import json
import time
from urllib.parse import urlencode
import pandas as pd
from selenium import webdriver
import bs4
import re
from lxml import etree

data=pd.read_excel(r"data/tmp/list.xlsx")

base_url = 'https://www.dianchacha.com/search/?k='

headers = {
    'Referer': 'https://weibo.com/u/2611704875?profile_ftype=1&is_all=1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}


def get_page( url ):
    
    try:
        response = requests.get(url, headers=headers,cookies = request_cookies)
#         print(response.text)
        if response.status_code == 200:
            return response.text
    except requests.ConnectionError as e:
        print('Error', e.args)
   

def main(): 
    df = pd.DataFrame([])
    
    for i,value in enumerate(data):

        
        text = get_page(value)
#         soup = bs4.BeautifulSoup(text, "lxml")
        html = etree.HTML(text)
        result = html.xpath('/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[3]/div[1]/a/span')
        print(result)
#             df = df.append(get_content(soup),ignore_index=True)
        break
    
#         data_list.append({
#                 '店铺名字': value,
#                 '描述相符': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[3]/div[1]/a/span').text,
#                 '服务态度': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[4]/div[1]/a/span').text,
#                 '物流服务': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[5]/div/a/span').text,
#                 '宝贝数': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[2]/li[1]/p[2]/a').text,
#                 '月销量': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[2]/li[2]/p[2]').text,
#                 '所在地区': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[3]/div[2]').text,
#                 '开店时间': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[2]/div[2]').text,
#                 '店铺收藏数': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[1]/ul[1]/li[4]/div[2]').text,
#                 '关联的店铺': browser.find_element_by_xpath( '/html/body/div[2]/div[2]/div[2]/div[7]/a[1]').text,

#         })
    
#     for page in range(1,max_page + 1 ):
#         for i in range(3):  #微博在每一页都会请求三次Ajax，第i页对应的pagebar, page,pre_page参数分别为(0,i,i-1),(0,i,i),(1,i,i)
#             if i==0 :
#                 text = get_page(0, page, page -1)             
#             elif i==1:
#                 text = get_page(0, page, page)
#             else :
#                 text = get_page(1, page, page)
#             soup = bs4.BeautifulSoup(text['data'], "lxml")
#             df = df.append(get_content(soup),ignore_index=True)
#     df.to_csv(r'D:\Anaconda3\ipython_file\python实验\实验一\微博数据.csv', encoding='gb18030')   #有些字符gbk没法识别，只能用gb18030格式
#     df
    print("爬取成功！")
main()
# Out:
# [<Element span at 0x1ae1f279408>]
# 爬取成功！
